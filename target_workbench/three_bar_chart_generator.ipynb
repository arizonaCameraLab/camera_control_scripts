# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

from target_toolbox.common import pixels_to_mm, dpi_to_pp
from target_toolbox.three_bar_chart import three_bar_target

# %%
dpi = 600
lw_list = (5, 4, 3, 2, 1.5, 1, 0.5) #in mm
mid_num = 3
PT = three_bar_target(lw_list, mid_num, dpi, center=True, tightness=8)

plt.figure(figsize=(8,8))
plt.imshow(PT, cmap='gray')
plt.title('Image width {:.2f} mm'.format(pixels_to_mm(PT.shape[0], dpi)))
plt.show()
